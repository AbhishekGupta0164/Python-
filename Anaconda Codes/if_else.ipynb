# %%
a=1
b=2
if a<b:
    print("a is less than b")
    print("a is definitely less then b")
print("not sure if a is less than b")
# Out:
# a is less than b
# a is definitely less then b
# not sure if a is less than b

# %%
c=9
d=4
if c<d:
    print("c is less than d")
else:
    print("c is not less than d")    
    print("i dont't think c is less than d")
print("outside the if block")
# Out:
# c is not less than d
# i dont't think c is less than d
# outside the if block

# %%
e=20
f=4
if e<f:
    print("e is less than f")
elif e == f:
    print("e is equal to f") 
elif e>f+10:
    print("e is greater than f by more than 10")
else:
    print("e is greater than f")
# Out:
# e is greater than f by more than 10

# %%
g=7
h=8
if g<h:
    print("g is less than h")
else:
    if g==h:
        print("g is equal to h")
    else:
        print("g is greate than h")
# Out:
# g is less than h

# %%
name ="VK"
height_m =2
weight_kg=100
bmi = weight_kg/(height_m**2)
print("bmi: ")
print(bmi)
if bmi<25:
    print(name)
    print("is not overweight")
else:
    print(name)
    print("is oerweight")
# Out:
# bmi:
# 25.0
# VK
# is oerweight
