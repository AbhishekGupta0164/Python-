# %%
a =["apple","banana","republic"]

# %%
for element in a:
    print(element)
# Out:
# apple
# banana
# republic

# %%
# for i in range(len(a)):  we use lenght of a  or direct
for i in range(3): #0,1,2 
    print(a[i])
# Out:
# apple
# banana
# republic

# %%
for i in range(3): #0,1,2 for printing value in order of 1,01,012 so add new for loop
    for j in range(i+1):
        #i=0 _> j=0
        #i=1 _> j=0,1
        #i=2 _> j=0,1,2
        print(a[i])
# Out:
# apple
# banana
# banana
# republic
# republic
# republic
