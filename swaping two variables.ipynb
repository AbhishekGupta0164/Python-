# %%
v1="hello"
v2="world"

# %%
temp1=v1
temp2=v2
v1=temp2
v2=temp1

# %%
print(v1)
# Out:
# world

# %%
print(v2)
# Out:
# hello

# %%
temp=v1
v1=v2
v2=temp

# %%
print(v1)
# Out:
# hello

# %%
print(v2)
# Out:
# world
