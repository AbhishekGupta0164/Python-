# %%
a =[3,10,-1]

# %%
print(a)
# Out:
# [3, 10, -1]

# %%
a.append(1)
print(a)
# Out:
# [3, 10, -1, 1]

# %%
a.append("hello")
print(a)
# Out:
# [3, 10, -1, 1, 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello']

# %%
a.pop()
print(a)
# Out:
# [3, 10, -1, 1, 'hello']

# %%
a.append([1,2])
print(a)
# Out:
# [3, 10, -1, 1, 'hello', [1, 2]]

# %%
a.pop()
print(a)
# Out:
# [3, 10, -1, 1, 'hello']

# %%
print(a[0])
# Out:
# 3

# %%
a[0]=100
print(a)
# Out:
# [100, 10, -1, 1, 'hello']

# %%
b=["banana","space","apple"]
print(b)
# Out:
# ['banana', 'space', 'apple']

# %%
temp =b[0]
b[0]=b[2];
b[2]=temp
print(b)
# Out:
# ['apple', 'space', 'banana']

# %%
#shortcut
b[0],b[2]=b[2],b[0]
print(b)
# Out:
# ['apple', 'space', 'banana']
