# %%
d = {}   
#d ={"Gorde": 24,"Tom": 32}

# %%
d["George"] = 24

# %%
d["Tom"] =32
d["Jenny"] =16

# %%
print(d["George"])
print(d["Tom"])
# print(d["Alien"]) error alien is known
# Out:
# 24
# 32

# %%
# keys are commonly string or numbers
d[10] =100

# %%
print(d[10])
# Out:
# 100

# %%
#how to iterate over key-value pairs?
# Source - https://stackoverflow.com/q
for key, value in d.items():
    print("key")
    print(key)
    print("value")
    print(value)
    print(" ")
# Out:
# key
# x
# value
# 1
#
# key
# y
# value
# 2
#
# key
# z
# value
# 3
